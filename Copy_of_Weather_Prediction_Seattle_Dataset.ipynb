# %% [markdown]
# <a href="https://colab.research.google.com/github/Ejemuta/Capstone-Project-Assignment/blob/master/Copy_of_Weather_Prediction_Seattle_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# read data into python as dataframe
df = pd.read_csv("/seattle-weather.csv")
df.head(10)

# %%
# @title date vs temp_max

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['date']
  ys = series['temp_max']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('date', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('weather')):
  _plot_series(series, series_name, i)
  fig.legend(title='weather', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('date')
_ = plt.ylabel('temp_max')

# %%
df.sample(10)

# %%
# prompt: Plot showing the distribution of weather for the year 2012

import matplotlib.pyplot as plt
# Filter data for the year 2012
df_2012 = df[df['date'].str.startswith('2012')]

# Plot the distribution of weather for 2012
plt.figure(figsize=(10, 6))
sns.countplot(x='weather', data=df_2012)
plt.title('Distribution of Weather in 2012')
plt.xlabel('Weather')
plt.ylabel('Count')
plt.show()

# %%
# prompt: Plot showing the distribution of weather for the year 2012 against 2013, 2014 and 2015

import matplotlib.pyplot as plt
# Filter data for the years 2012, 2013, 2014, and 2015
df_2012 = df[df['date'].str.startswith('2012')]
df_2013 = df[df['date'].str.startswith('2013')]
df_2014 = df[df['date'].str.startswith('2014')]
df_2015 = df[df['date'].str.startswith('2015')]

# Create subplots for each year
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Distribution of Weather for 2012-2015')

# Plot the distribution for 2012
sns.countplot(x='weather', data=df_2012, ax=axes[0, 0])
axes[0, 0].set_title('2012')
axes[0, 0].set_xlabel('Weather')
axes[0, 0].set_ylabel('Count')

# Plot the distribution for 2013
sns.countplot(x='weather', data=df_2013, ax=axes[0, 1])
axes[0, 1].set_title('2013')
axes[0, 1].set_xlabel('Weather')
axes[0, 1].set_ylabel('Count')

# Plot the distribution for 2014
sns.countplot(x='weather', data=df_2014, ax=axes[1, 0])
axes[1, 0].set_title('2014')
axes[1, 0].set_xlabel('Weather')
axes[1, 0].set_ylabel('Count')

# Plot the distribution for 2015
sns.countplot(x='weather', data=df_2015, ax=axes[1, 1])
axes[1, 1].set_title('2015')
axes[1, 1].set_xlabel('Weather')
axes[1, 1].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %%
# prompt: Plot showing the distribution of weather for the year 2012 against 2013, 2014 and 2015, use different charts like line plot and others, make the plot on one graph

import matplotlib.pyplot as plt

# Group weather data by year and count occurrences
weather_counts_2012 = df_2012.groupby('weather')['weather'].count()
weather_counts_2013 = df_2013.groupby('weather')['weather'].count()
weather_counts_2014 = df_2014.groupby('weather')['weather'].count()
weather_counts_2015 = df_2015.groupby('weather')['weather'].count()

# Create a figure and axes for the plot
fig, ax = plt.subplots(figsize=(12, 6))

# Define colors for each year
colors = ['blue', 'green', 'red', 'orange']

# Plot the distribution for each year using a line plot
ax.plot(weather_counts_2012.index, weather_counts_2012.values, label='2012', color=colors[0])
ax.plot(weather_counts_2013.index, weather_counts_2013.values, label='2013', color=colors[1])
ax.plot(weather_counts_2014.index, weather_counts_2014.values, label='2014', color=colors[2])
ax.plot(weather_counts_2015.index, weather_counts_2015.values, label='2015', color=colors[3])

# Customize the plot
ax.set_xlabel('Weather')
ax.set_ylabel('Count')
ax.set_title('Distribution of Weather for 2012-2015')
ax.legend()

# Add a grid for better readability
ax.grid(True)

plt.show()

# %%
df.shape

# %%
df.info()

# %%
df.columns

# %%
df.isnull().sum()

# %%
msno.matrix(df, figsize=(10,5), fontsize=12, color = (1, 0.38, 0.30))

# %%
df.describe()

# %%
df1 = df.drop(['date', 'weather'],axis=1)
df1.describe()

# %%
print(df.shape)
print(df1.shape)

# %%
df.duplicated().sum()

# %%
df[df['temp_min']==min(df.temp_min)]

# %%
df[df['temp_max']==max(df.temp_max)]

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=df,x=df.temp_max,bins=20)

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=df,x=df.temp_min,bins=20)

# %%
df.loc[:,['date','temp_max']]
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# # Max temperature in each month in each year

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
g = sns.FacetGrid(df, col='year', col_wrap=4, height=4)
g.map(sns.lineplot, 'month', 'temp_max')
g.set_axis_labels('Month', 'Max Temperature (°C)')
g.set_titles(col_template="{col_name}")
plt.show()

# %% [markdown]
# # Min temperature in each month in each year

# %%
g = sns.FacetGrid(df, col='year', col_wrap=4, height=4)
g.map(sns.lineplot, 'month', 'temp_min')
g.set_axis_labels('Month', 'Min Temperature (°C)')
g.set_titles(col_template="{col_name}")
plt.show()

# %% [markdown]
# # Precipitation in each month in each year

# %%
g = sns.FacetGrid(df, col='year', col_wrap=4, height=4)
g.map(sns.scatterplot, 'month', 'precipitation')
g.set_axis_labels('Month', 'Precipitation')
g.set_titles(col_template="{col_name}")
plt.show()

# %%
g = sns.FacetGrid(df, col='year', col_wrap=4, height=5)
g.map(sns.scatterplot, 'month', 'wind')
g.set_axis_labels('Month', 'Wind speed')
g.set_titles(col_template="{col_name}")
plt.show()

# %%
df.weather.value_counts()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df,x=df.weather)

# %%
x=df.weather.value_counts()
plt.figure(figsize=(12, 10))
plt.pie(x, labels=x.index, autopct='%1.1f%%', startangle=90, colors=['lightblue', 'gold', 'lightgray', 'lightgreen', 'lightcoral'])
plt.title('Distribution of Weather Types')
plt.show()

# %%
df.drop('month',axis=1,inplace=True)
df.drop('year',axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

df.info()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['weather']=le.fit_transform(df['weather'])

# %%
x = df[['temp_min', 'temp_max', 'precipitation', 'wind']]
y=df['weather']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

nb_model = GaussianNB()
nb_model.fit(X_train, y_train)

y_pred = nb_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred, zero_division=1)


print(f"Accuracy: {accuracy:.2f}")

# %%
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(classification_rep)

# %%
# prompt: Use colours to display confusion matrix

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds',
            xticklabels=['drizzle', 'fog', 'rain', 'snow', 'sun'],
            yticklabels=['drizzle', 'fog', 'rain', 'snow', 'sun'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
# prompt: Try out different ensemble and advanced Machine Learning Algorithms to see if the accuracy will increase

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# Random Forest
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"Random Forest Accuracy: {accuracy_rf:.2f}")

# Gradient Boosting
gb_model = GradientBoostingClassifier(random_state=42)
gb_model.fit(X_train, y_train)
y_pred_gb = gb_model.predict(X_test)
accuracy_gb = accuracy_score(y_test, y_pred_gb)
print(f"Gradient Boosting Accuracy: {accuracy_gb:.2f}")

# Support Vector Machine (SVM)
svm_model = SVC(random_state=42)
svm_model.fit(X_train, y_train)
y_pred_svm = svm_model.predict(X_test)
accuracy_svm = accuracy_score(y_test, y_pred_svm)
print(f"SVM Accuracy: {accuracy_svm:.2f}")


# Hyperparameter tuning for Random Forest (optional)
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]
}
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
best_rf_model = grid_search.best_estimator_
y_pred_best_rf = best_rf_model.predict(X_test)
accuracy_best_rf = accuracy_score(y_test, y_pred_best_rf)
print(f"Tuned Random Forest Accuracy: {accuracy_best_rf:.2f}")

# %%
# prompt: Estimate the confusion matrix and classification report for the above models and use colours to display confusion matrix

import matplotlib.pyplot as plt
def evaluate_and_plot_confusion_matrix(model, X_test, y_test, model_name):
  """Evaluates the model and plots the confusion matrix with colors."""
  y_pred = model.predict(X_test)
  conf_matrix = confusion_matrix(y_test, y_pred)
  classification_rep = classification_report(y_test, y_pred, zero_division=1)

  print(f"{model_name} Classification Report:")
  print(classification_rep)

  plt.figure(figsize=(8, 6))
  sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds',
              xticklabels=['drizzle', 'fog', 'rain', 'snow', 'sun'],
              yticklabels=['drizzle', 'fog', 'rain', 'snow', 'sun'])
  plt.xlabel('Predicted')
  plt.ylabel('Actual')
  plt.title(f'Confusion Matrix for {model_name}')
  plt.show()


# Evaluate and plot for Naive Bayes
evaluate_and_plot_confusion_matrix(nb_model, X_test, y_test, "Naive Bayes")

# Evaluate and plot for Random Forest
evaluate_and_plot_confusion_matrix(rf_model, X_test, y_test, "Random Forest")

# Evaluate and plot for Gradient Boosting
evaluate_and_plot_confusion_matrix(gb_model, X_test, y_test, "Gradient Boosting")

# Evaluate and plot for SVM
evaluate_and_plot_confusion_matrix(svm_model, X_test, y_test, "SVM")

# Evaluate and plot for Tuned Random Forest
evaluate_and_plot_confusion_matrix(best_rf_model, X_test, y_test, "Tuned Random Forest")

# %%
# prompt: Using the best model prediction above and what is the weather condition for inputs (temp_min = 5, temp_max = 16, precipitation = 30, wind = 2.5)

import pandas as pd
# Use the best model (e.g., Tuned Random Forest) to predict the weather
new_data = pd.DataFrame({'temp_min': [5], 'temp_max': [16], 'precipitation': [30], 'wind': [2.5]})
predicted_weather_label = best_rf_model.predict(new_data)[0]

# Reverse the label encoding to get the actual weather condition
weather_labels = le.inverse_transform([predicted_weather_label])

print(f"Predicted weather condition: {weather_labels[0]}")

# %%
# prompt: What is the model you used above?

# The models used above are:
# 1. Naive Bayes (GaussianNB)
# 2. Random Forest (RandomForestClassifier)
# 3. Gradient Boosting (GradientBoostingClassifier)
# 4. Support Vector Machine (SVC)
# 5. Tuned Random Forest (GridSearchCV with RandomForestClassifier)

# These models were used for predicting the weather based on the provided dataset.

# The best model among them was identified as the Tuned Random Forest based on its accuracy score.
# In this experiment, the best model achieved an accuracy of around 0.80
